# %%
import pandas as pd

# %%
# Read in file
df = pd.read_csv("Resources/2019-citibike-all2.csv")
df.head()
# Out:
#    tripduration (min)                 starttime                  stoptime  \
# 0            3.350000  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1            8.416667  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           12.600000  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3           26.250000  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4           26.100000  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# 1               -74.033459            3638       Washington St
# 2               -74.033459            3192  Liberty Light Rail
# 3               -74.033459            3638       Washington St
# 4               -74.033459            3638       Washington St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.712774             -74.036486   29612  Subscriber
# 1             40.724294             -74.035483   29213  Subscriber
# 2             40.711242             -74.055701   26164  Subscriber
# 3             40.724294             -74.035483   29672    Customer
# 4             40.724294             -74.035483   29522    Customer
#
#    birth year   gender     rideid  tripdistance (mi)
# 0        1993     Male  3183_3214           0.287680
# 1        1972   Female  3183_3638           0.566222
# 2        1985     Male  3183_3192           1.215543
# 3        1969  Unknown  3183_3638           0.566222
# 4        1969  Unknown  3183_3638           0.566222

# %%
# Select desired columns by index
df2 = df.iloc[:,3:12]
df2.head()
# Out:
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# 1               -74.033459            3638       Washington St
# 2               -74.033459            3192  Liberty Light Rail
# 3               -74.033459            3638       Washington St
# 4               -74.033459            3638       Washington St
#
#    end station latitude  end station longitude  bikeid
# 0             40.712774             -74.036486   29612
# 1             40.724294             -74.035483   29213
# 2             40.711242             -74.055701   26164
# 3             40.724294             -74.035483   29672
# 4             40.724294             -74.035483   29522

# %%
# Add Ride ID column to data frame
df2["rideid"] = df["rideid"]
df2.head()
# Out:
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# 1               -74.033459            3638       Washington St
# 2               -74.033459            3192  Liberty Light Rail
# 3               -74.033459            3638       Washington St
# 4               -74.033459            3638       Washington St
#
#    end station latitude  end station longitude  bikeid     rideid
# 0             40.712774             -74.036486   29612  3183_3214
# 1             40.724294             -74.035483   29213  3183_3638
# 2             40.711242             -74.055701   26164  3183_3192
# 3             40.724294             -74.035483   29672  3183_3638
# 4             40.724294             -74.035483   29522  3183_3638

# %%
# Make new column names
columns = ["Start/End", "Ride ID", "Station ID", "Station Name", "Latitude", "Longitude", "Bike ID"]

# %%
# Create empty data frames to store info
df3 = pd.DataFrame(columns=columns)
df4 = pd.DataFrame(columns=columns)

# %%
# Populate df3 with 'ride start' info
df3["Ride ID"] = df2["rideid"]
df3["Station ID"] = df2["start station id"]
df3["Station Name"] = df2["start station name"]
df3["Latitude"] = df2["start station latitude"]
df3["Longitude"] = df2["start station longitude"]
df3["Bike ID"] = df2["bikeid"]

# %%
df3["Start/End"] = "Start"
df3.tail()
# Out:
#        Start/End    Ride ID  Station ID      Station Name   Latitude  \
# 248279     Start  3639_3203        3639        Harborside  40.719252
# 248280     Start  3186_3185        3186     Grove St PATH  40.719586
# 248281     Start  3276_3211        3276  Marin Light Rail  40.714584
# 248282     Start  3211_3209        3211        Newark Ave  40.721525
# 248283     Start  3185_3277        3185         City Hall  40.717733
#
#         Longitude  Bike ID
# 248279 -74.034234    29522
# 248280 -74.043117    29679
# 248281 -74.042817    26198
# 248282 -74.046305    29512
# 248283 -74.043845    26223

# %%
# Populate df4 with 'ride end' info
df4["Ride ID"] = df2["rideid"]
df4["Station ID"] = df2["end station id"]
df4["Station Name"] = df2["end station name"]
df4["Latitude"] = df2["end station latitude"]
df4["Longitude"] = df2["end station longitude"]
df4["Bike ID"] = df2["bikeid"]

# %%
df4["Start/End"] = "End"
df4.head()
# Out:
#   Start/End    Ride ID  Station ID        Station Name   Latitude  Longitude  \
# 0       End  3183_3214        3214    Essex Light Rail  40.712774 -74.036486
# 1       End  3183_3638        3638       Washington St  40.724294 -74.035483
# 2       End  3183_3192        3192  Liberty Light Rail  40.711242 -74.055701
# 3       End  3183_3638        3638       Washington St  40.724294 -74.035483
# 4       End  3183_3638        3638       Washington St  40.724294 -74.035483
#
#    Bike ID
# 0    29612
# 1    29213
# 2    26164
# 3    29672
# 4    29522

# %%
df5 = pd.concat([df3, df4])
df5.tail()
# Out:
#        Start/End    Ride ID  Station ID             Station Name   Latitude  \
# 248279       End  3639_3203        3203            Hamilton Park  40.727596
# 248280       End  3186_3185        3185                City Hall  40.717733
# 248281       End  3276_3211        3211               Newark Ave  40.721525
# 248282       End  3211_3209        3209             Brunswick St  40.724176
# 248283       End  3185_3277        3277  Communipaw & Berry Lane  40.714358
#
#         Longitude  Bike ID
# 248279 -74.044247    29522
# 248280 -74.043845    29679
# 248281 -74.046305    26198
# 248282 -74.050656    29512
# 248283 -74.066611    26223

# %%
df5 = df5.sort_values(by=["Ride ID"])
df5.head()
# Out:
#        Start/End    Ride ID  Station ID            Station Name   Latitude  \
# 59482      Start   3183_224        3183          Exchange Place  40.716247
# 59482        End   3183_224         224   Spruce St & Nassau St  40.711464
# 101815       End   3183_311         311  Norfolk St & Broome St  40.717227
# 101815     Start   3183_311        3183          Exchange Place  40.716247
# 19268        End  3183_3184        3184             Paulus Hook  40.714145
#
#         Longitude  Bike ID
# 59482  -74.033459    29287
# 59482  -74.005524    29287
# 101815 -73.988021    29616
# 101815 -74.033459    29616
# 19268  -74.033552    26221

# %%
df6 = df5.reset_index(drop=True)
df6.head()
# Out:
#   Start/End    Ride ID  Station ID            Station Name   Latitude  \
# 0     Start   3183_224        3183          Exchange Place  40.716247
# 1       End   3183_224         224   Spruce St & Nassau St  40.711464
# 2       End   3183_311         311  Norfolk St & Broome St  40.717227
# 3     Start   3183_311        3183          Exchange Place  40.716247
# 4       End  3183_3184        3184             Paulus Hook  40.714145
#
#    Longitude  Bike ID
# 0 -74.033459    29287
# 1 -74.005524    29287
# 2 -73.988021    29616
# 3 -74.033459    29616
# 4 -74.033552    26221

# %%
df6.to_csv("Resources/ride-paths.csv", index=False)
